# %%
import math
import numpy as np
import os
import shutil
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# Load the training and testing data (already created CSVs)
train_df = pd.read_csv('train_pixel_data.csv')  # Training data
test_df = pd.read_csv('test_pixel_data.csv')    # Testing data

# Separate features (RGB values) and labels
X_train = train_df[['R', 'G', 'B']].values  # RGB values as features
Y_train = train_df['Class_Label'].values    # Labels for training set

X_test = test_df[['R', 'G', 'B']].values    # RGB values as features
Y_test = test_df['Class_Label'].values      # Labels for testing set

# Normalize pixel values to the range 0 to 1 
X_train = X_train / 255.0
X_test = X_test / 255.0

# Shuffle the training data
np.random.seed(42)  
shuffled_indices = np.random.permutation(len(X_train))
X_train = X_train[shuffled_indices]
Y_train = Y_train[shuffled_indices]

print(f"Training set shape: X_train: {X_train.shape}, Y_train: {Y_train.shape}")
print(f"Testing set shape: X_test: {X_test.shape}, Y_test: {Y_test.shape}")

print("\nFirst few rows of the training data:")
print(train_df.head())

print("\nFirst few rows of the testing data:")
print(test_df.head())
# Out:
# Training set shape: X_train: (347602944, 3), Y_train: (347602944,)
# Testing set shape: X_test: (84738048, 3), Y_test: (84738048,)
#
# First few rows of the training data:
#      R    G    B  Class_Label
# 0  255  255  255            3
# 1  255  255  255            3
# 2  255  255  255            3
# 3  255  255  255            3
# 4  255  255  255            3
#
# First few rows of the testing data:
#      R    G    B  Class_Label
# 0  216  213  198            2
# 1  216  213  198            2
# 2  216  213  198            2
# 3  216  213  198            2
# 4  216  213  198            2

# %%
def relu(x):
    return max(0,x)

def softmax(Z):
    return np.exp(Z) / np.sum(exp(Z))

# %%
class Neuron():
    def __init__(self,weights,bias,layer):
        self.weights = weights
        self.bias = bias
        self.layer = layer

# %%
def init_params():
    W1 = np.random.randn(10,784) -0.5
    b1 = np.random.radn(10,1) -0.5
    W2 = np.random.rand(10,10) -0.5
    b2 = np.random.randn(10,1) -0.5
    return W1,b1,W2,b2

def one_hot():
    #creates correctly sized array
    one_hot_Y = np.zeros(Y.size, Y.max()+1)
    one_hot_Y[np.arrange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def forward_prop(W1,b1,W2,b2,X):
    Z1 = W1.dot(X) + b1
    A1 = relu(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = softmax(A1)
    return Z1,A1,Z2,A2

def backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y):
    one_hot_Y = one_hot(Y)
    dZ2 = A2 - one_hot_Y
    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2)
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)
    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1)
    return dW1, db1, dW2, db2
    
#https://www.youtube.com/watch?v=w8yWXqWQYmU&t=500s
